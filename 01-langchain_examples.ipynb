# %%
from langchain_openai import ChatOpenAI
import getpass
import os

# %%
os.environ["OPENAI_API_KEY"] = getpass.getpass("Enter your OpenAI API key: ")
# Out:
# Enter your OpenAI API key:  ········

# %%
llm = ChatOpenAI(openai_api_key=OPENAI_API_KEY,
model_name="gpt-5-nano")
llm.invoke("It's a hot day, I would like to go to the…")
# Out:
# AIMessage(content='Nice idea. Here are some great ways to beat the heat, depending on what you’re in the mood for:\n\nIndoor options (cool and easy)\n- Visit an air-conditioned mall for a stroll, coffee, and perhaps a movie.\n- Go to a museum, aquarium, or science center.\n- Hit a library or a bookstore café for a quiet break.\n- Find a coffee shop or ice cream shop with outdoor seating if you want a short outdoor breath of fresh air.\n\nOutdoor but shaded/water options\n- Find a public pool, splash pad, or a lake/beach for a dip.\n- Look for a shady park with a breeze, maybe bring a picnic and a fan.\n- Try a botanical garden conservatory or a greenhouse for cooler, breezy air.\n\nQuick plan ideas\n- 1–2 hour: Pool or splash pad, then a cold drink nearby.\n- Half-day: Museum or aquarium + café stop for something refreshing.\n- All-day: Water park or a beach day with breaks in the shade.\n\nIf you tell me your city or approximate area, I can suggest specific places. Also, do you prefer indoors or outdoors, and are you with friends/family or solo?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 1275, 'prompt_tokens': 19, 'total_tokens': 1294, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 1024, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-E4SqOtI5PGauu8Axv9260cpleEF5b', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019f8a5e-cd0d-7b31-85a0-a3b1fc414362-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 19, 'output_tokens': 1275, 'total_tokens': 1294, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 1024}})

# %%
prompt_input = """Write a short message to remind users to be
vigilant about phishing attacks."""
response = llm.invoke(prompt_input)
print(response.content)
# Out:
# Reminder: Be vigilant against phishing. Don’t click suspicious links or share passwords. If in doubt, verify with the official channel and hover over links to check URLs before you click.
